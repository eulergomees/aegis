# %%
from pathlib import Path
from ml.dataset import ImageDataset
from ml.transforms import train_transform

dataset = ImageDataset(
    csv_path=Path("../data/raw/HAM10000_metadata.csv"),
    img_dirs=[
        Path("../data/raw/HAM10000_images_part_1"),
        Path("../data/raw/HAM10000_images_part_2"),
    ],
    transform=train_transform
)

print(len(dataset))
img, label = dataset[0]
print(type(img), label)
img
# Out:
# tensor([[[-1.7412, -1.7412, -1.7412,  ..., -1.7412, -1.7412, -1.7412],
#          [-1.7412, -1.7412, -1.7412,  ..., -1.7412, -1.7412, -1.7412],
#          [-1.7412, -1.7412, -1.7412,  ..., -1.7412, -1.7412, -1.7412],
#          ...,
#          [-1.7412, -1.7412, -1.7412,  ..., -1.7412, -1.7412, -1.7412],
#          [-1.7412, -1.7412, -1.7412,  ..., -1.7412, -1.7412, -1.7412],
#          [-1.7412, -1.7412, -1.7412,  ..., -1.7412, -1.7412, -1.7412]],
#
#         [[-1.6506, -1.6506, -1.6506,  ..., -1.6506, -1.6506, -1.6506],
#          [-1.6506, -1.6506, -1.6506,  ..., -1.6506, -1.6506, -1.6506],
#          [-1.6506, -1.6506, -1.6506,  ..., -1.6506, -1.6506, -1.6506],
#          ...,
#          [-1.6506, -1.6506, -1.6506,  ..., -1.6506, -1.6506, -1.6506],
#          [-1.6506, -1.6506, -1.6506,  ..., -1.6506, -1.6506, -1.6506],
#          [-1.6506, -1.6506, -1.6506,  ..., -1.6506, -1.6506, -1.6506]],
#
#         [[-1.4210, -1.4210, -1.4210,  ..., -1.4210, -1.4210, -1.4210],
#          [-1.4210, -1.4210, -1.4210,  ..., -1.4210, -1.4210, -1.4210],
#          [-1.4210, -1.4210, -1.4210,  ..., -1.4210, -1.4210, -1.4210],
#          ...,
#          [-1.4210, -1.4210, -1.4210,  ..., -1.4210, -1.4210, -1.4210],
#          [-1.4210, -1.4210, -1.4210,  ..., -1.4210, -1.4210, -1.4210],
#          [-1.4210, -1.4210, -1.4210,  ..., -1.4210, -1.4210, -1.4210]]])
